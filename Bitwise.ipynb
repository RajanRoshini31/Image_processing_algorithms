# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
def bitwise_operations_demo(image1_path, image2_path):
    img1 = cv.imread(image1_path)
    img2 = cv.imread(image2_path)

    if img1.shape != img2.shape:
      raise ValueError("Image must have the same dimensions for these operations")
    and_operator =cv.bitwise_and(img1, img2)
    or_operator = cv.bitwise_or(img1, img2)
    xor_operator = cv.bitwise_xor(img1, img2)
    not_operator_img1 = cv.bitwise_not(img1)
    not_operator_img2 = cv.bitwise_not(img2)

    add_operator = cv.add(img1, img2)
    sub_operator = cv.subtract(img1, img2)

    left_shift_operator =cv.convertScaleAbs(img1*4)
    right_shift_operator = cv.convertScaleAbs(img1/4)

    print("Original Image1")
    cv2_imshow(img1)
    print("Original Image2")
    cv2_imshow(img2)

    print("Bitwise AND")
    cv2_imshow(and_operator)
    print("Bitwise OR")
    cv2_imshow(or_operator)
    print("Bitwise XOR")
    cv2_imshow(xor_operator)
    print("Bitwise NOT on Image1")
    cv2_imshow(not_operator_img1)
    print("Bitwise NOT on Image2")
    cv2_imshow(not_operator_img2)

    print("Addition")
    cv2_imshow(add_operator)
    print("Subtraction")
    cv2_imshow(sub_operator)

    print("Left Shift on Image1")
    cv2_imshow(left_shift_operator)
    print("Right Shift on Image1")
    cv2_imshow(right_shift_operator)

    cv.waitKey(0)
    cv.destroyAllWindows()
image1_path='/content/one.jpg'
image2_path='/content/second.jpg'
bitwise_operations_demo(image1_path, image2_path)
# Out:
# Original Image1
# <PIL.Image.Image image mode=RGB size=256x256>
# Original Image2
# <PIL.Image.Image image mode=RGB size=256x256>
# Bitwise AND
# <PIL.Image.Image image mode=RGB size=256x256>
# Bitwise OR
# <PIL.Image.Image image mode=RGB size=256x256>
# Bitwise XOR
# <PIL.Image.Image image mode=RGB size=256x256>
# Bitwise NOT on Image1
# <PIL.Image.Image image mode=RGB size=256x256>
# Bitwise NOT on Image2
# <PIL.Image.Image image mode=RGB size=256x256>
# Addition
# <PIL.Image.Image image mode=RGB size=256x256>
# Subtraction
# <PIL.Image.Image image mode=RGB size=256x256>
# Left Shift on Image1
# <PIL.Image.Image image mode=RGB size=256x256>
# Right Shift on Image1
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
def bitwise_operations_demo(image1_path, image2_path):
    img1 = cv.imread(image1_path)
    img2 = cv.imread(image2_path)

    if img1.shape != img2.shape:
      raise ValueError("Image must have the same dimensions for these operations")
    and_operator =cv.bitwise_and(img1, img2)
    or_operator = cv.bitwise_or(img1, img2)
    xor_operator = cv.bitwise_xor(img1, img2)
    not_operator_img1 = cv.bitwise_not(img1)
    not_operator_img2 = cv.bitwise_not(img2)

    add_operator = cv.add(img1, img2)
    sub_operator = cv.subtract(img1, img2)

    left_shift_operator =cv.convertScaleAbs(img1*4)
    right_shift_operator = cv.convertScaleAbs(img1/4)
    print("Original Image 1")
    plt.imshow(img1)
    plt.show()
    print("Original Image 2")
    plt.imshow(img2)
    plt.show()

    print("Bitwise AND")
    plt.imshow(and_operator)
    plt.show()
    print("Bitwise OR")
    plt.imshow(or_operator)
    plt.show()
    print("Bitwise XOR")
    plt.imshow(xor_operator)
    plt.show()
    print("Bitwise NOT on Image1")
    plt.imshow(not_operator_img1)
    plt.show()
    print("Bitwise NOT on Image2")
    plt.imshow(not_operator_img2)
    plt.show()

    print("Addition")
    plt.imshow(add_operator)
    plt.show()
    print("Subtraction")
    plt.imshow(sub_operator)
    plt.show()

    print("Left Shift on Image1")
    plt.imshow(left_shift_operator)
    plt.show()
    print("Right Shift on Image1")
    plt.imshow(right_shift_operator)
    plt.show()
image1_path='/content/one.jpg'
image2_path='/content/second.jpg'
bitwise_operations_demo(image1_path, image2_path)
# Out:
# Original Image 1
# Original Image 2
# Bitwise AND
# Bitwise OR
# Bitwise XOR
# Bitwise NOT on Image1
# Bitwise NOT on Image2
# Addition
# Subtraction
# Left Shift on Image1
# Right Shift on Image1
